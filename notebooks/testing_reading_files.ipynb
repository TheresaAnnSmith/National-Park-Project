# %%
import pandas as pd

# %%
parks_df = pd.read_csv('../data/parks.csv') # I put this in the data folder in my python folder

# %%
parks_df # this one does not list them all
# Out:
#    Park Code                                       Park Name       State  \
# 0       ACAD                            Acadia National Park          ME
# 1       ARCH                            Arches National Park          UT
# 2       BADL                          Badlands National Park          SD
# 3       BIBE                          Big Bend National Park          TX
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# ...

# %%
parks_df['Acres'].max()
# Out:
# 8323148

# %%
biggest = parks_df.loc[parks_df['Acres'] == 8323148]
biggest
# Out:
#    Park Code                                       Park Name State    Acres  \
# 52      WRST  Wrangell - St Elias National Park and Preserve    AK  8323148
#
#     Latitude  Longitude
# 52      61.0     -142.0

# %%
parks_df.sort_values(by= 'Acres', ascending = False)
# Out:
#    Park Code                                       Park Name       State  \
# 52      WRST  Wrangell - St Elias National Park and Preserve          AK
# 18      GAAR  Gates Of The Arctic National Park and Preserve          AK
# 15      DEVA                      Death Valley National Park      CA, NV
# 32      KATM               Katmai National Park and Preserve          AK
# 14      DENA               Denali National Park and Preserve          AK
# 20      GLBA          Glacier Bay National Park and Preserve          AK
# 35      LACL           Lake Clark National Park and Preserve          AK
# 53      YELL                       Yellowstone National Park  WY, MT, ID
# 34      KOVA                      Kobuk Valley National Park          AK
# 17      EVER                        Everglades National Park          FL
# 22      GRCA                      Grand Canyon National Park          AZ
# 19      GLAC                           Glacier National Park          MT
# ...

# %%
parks_df['State'].value_counts()
# Out:
# AK            8
# CA            7
# UT            5
# CO            4
# FL            3
# AZ            3
# WA            3
# SD            2
# TX            2
# HI            2
# ME            1
# MI            1
# ND            1
# KY            1
# VA            1
# MN            1
# AR            1
# MT            1
# WY            1
# TN, NC        1
# NV            1
# CA, NV        1
# OH            1
# OR            1
# SC            1
# NM            1
# WY, MT, ID    1
# Name: State, dtype: int64

# %%
test_2 = pd.read_excel('../data/visitors_1980_2000.xlsx')  # reading in excel looks really ugly 
test_2
# Out:
#      Unnamed: 0                                       Unnamed: 1  \
# 0           NaN  Annual Visitation Report by Years: 1980 to 2000
# 1           NaN                                              NaN
# 2           NaN                                              NaN
# 3           NaN                                              NaN
# 4           NaN                                              NaN
# ..          ...                                              ...
# 345         NaN                                              NaN
# 346         NaN                                              NaN
# 347         NaN                                              NaN
# 348         NaN                                              NaN
# 349         NaN                                              NaN
#
#                                             Unnamed: 2           Unnamed: 3  \
# 0                                                  NaN                  NaN
# ...

# %%
suicides_df = pd.read_csv('../data/suicides.csv')

# %%
suicides_df
# Out:
#      Calendar Year Cause of Death Injury Category           Sex     Age Range  \
# 0             2014        Suicide     Intentional          Male         55-64
# 1             2014        Suicide     Intentional        Female         35-44
# 2             2014        Suicide     Intentional        Female         35-44
# 3             2014        Suicide     Intentional          Male           65+
# 4             2014        Suicide     Intentional          Male         25-34
# ..             ...            ...             ...           ...           ...
# 408           2021        Suicide     Intentional          Male         25-34
# 409           2021        Suicide     Intentional  Undetermined  Undetermined
# 410           2021        Suicide     Intentional          Male           65+
# 411           2021        Suicide     Intentional        Female         15-24
# 412           2021        Suicide     Intentional        Female         25-34
#
#           Outcome
# ...

# %%
visitors_1979  = pd.read_csv('../data/visitors_in_1979.csv')

# %%
visitors_1979.head(10) # need to clean it up
# Out:
#    Annual Visitation Report by Years: 1978 to 1979  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
#
#                                           Unnamed: 1           Unnamed: 2  \
# 0                                                NaN                  NaN
# 1  This report will not correctly export to CSV. ...                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN  Recreational Visits
# ...

# %%
visitors_1979.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 4 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Annual Visitation Report by Years: 1978 to 1979  0 non-null      float64
#  1   Unnamed: 1                                       267 non-null    object
#  2   Unnamed: 2                                       267 non-null    object
#  3   Unnamed: 3                                       266 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 8.6+ KB

# %%
visitors_1979.drop(visitors_1979.columns[[0,3]], axis=1, inplace=True)

# %%
visitors_1979.head(10)
# Out:
#                                           Unnamed: 1           Unnamed: 2
# 0                                                NaN                  NaN
# 1  This report will not correctly export to CSV. ...                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN  Recreational Visits
# 4                                          Park Name                 1979
# 5                                          Acadia NP            2,787,366
# 6                                          Adams NHP               34,322
# 7                               Agate Fossil Beds NM                8,115
# 8                         Alibates Flint Quarries NM                1,922
# 9                     Allegheny Portage Railroad NHS               58,225

# %%
visitors_1979 = visitors_1979.rename(columns={'Unnamed: 1': 'Park Name','Unnamed: 2':'Visitors'})

# %%
visitors_1979.head(10)
# Out:
#                                            Park Name             Visitors
# 0                                                NaN                  NaN
# 1  This report will not correctly export to CSV. ...                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN  Recreational Visits
# 4                                          Park Name                 1979
# 5                                          Acadia NP            2,787,366
# 6                                          Adams NHP               34,322
# 7                               Agate Fossil Beds NM                8,115
# 8                         Alibates Flint Quarries NM                1,922
# 9                     Allegheny Portage Railroad NHS               58,225

# %%
visitors_1979 = visitors_1979.drop(visitors_1979.index[[0,1,2,3,4]])  # dropping rows I don't need

# %%
visitors_1979.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 5 to 269
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Park Name  265 non-null    object
#  1   Visitors   265 non-null    object
# dtypes: object(2)
# memory usage: 4.3+ KB

# %%
visitors_1979
# Out:
#                           Park Name   Visitors
# 5                         Acadia NP  2,787,366
# 6                         Adams NHP     34,322
# 7              Agate Fossil Beds NM      8,115
# 8        Alibates Flint Quarries NM      1,922
# 9    Allegheny Portage Railroad NHS     58,225
# ..                              ...        ...
# 265            Wright Brothers NMEM    396,322
# 266                      Wupatki NM    186,875
# 267                  Yellowstone NP  1,892,908
# 268                     Yosemite NP  2,350,782
# 269                         Zion NP  1,040,528
#
# [265 rows x 2 columns]

# %%
visitors_1979 = visitors_1979.reset_index(drop = True)
visitors_1979.head(10)
# Out:
#                         Park Name   Visitors
# 0                       Acadia NP  2,787,366
# 1                       Adams NHP     34,322
# 2            Agate Fossil Beds NM      8,115
# 3      Alibates Flint Quarries NM      1,922
# 4  Allegheny Portage Railroad NHS     58,225
# 5                     Amistad NRA  1,261,846
# 6               Andersonville NHS    151,123
# 7              Andrew Johnson NHS     47,674
# 8                     Antietam NB    319,610
# 9              Apostle Islands NL     75,629

# %%
visitors_1979.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Park Name  265 non-null    object
#  1   Visitors   265 non-null    object
# dtypes: object(2)
# memory usage: 4.3+ KB

# %%
visitors_1979.dtypes
# Out:
# Park Name    object
# Visitors     object
# dtype: object

# %%
visitors_1979['Visitors'] = visitors_1979['Visitors'].str.replace(',','') # getting rid of the ,

# %%
visitors_1979
# Out:
#                           Park Name Visitors
# 0                         Acadia NP  2787366
# 1                         Adams NHP    34322
# 2              Agate Fossil Beds NM     8115
# 3        Alibates Flint Quarries NM     1922
# 4    Allegheny Portage Railroad NHS    58225
# ..                              ...      ...
# 260            Wright Brothers NMEM   396322
# 261                      Wupatki NM   186875
# 262                  Yellowstone NP  1892908
# 263                     Yosemite NP  2350782
# 264                         Zion NP  1040528
#
# [265 rows x 2 columns]

# %%
visitors_1979['Visitors'] = visitors_1979['Visitors'].astype(int) # now that the , is gone we can convert to int

# %%
visitors_1979.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Park Name  265 non-null    object
#  1   Visitors   265 non-null    int32
# dtypes: int32(1), object(1)
# memory usage: 3.2+ KB

# %%
max_visitors = visitors_1979.groupby('Park Name')['Visitors'].max().sort_values(ascending = False).to_frame().reset_index().head(1)

# %%
max_visitors # max visited
# Out:
#          Park Name  Visitors
# 0  Blue Ridge PKWY  11700219

# %%
visitors_1979.describe()
# Out:
#            Visitors
# count  2.650000e+02
# mean   7.466893e+05
# std    1.568789e+06
# min    3.710000e+02
# 25%    6.828800e+04
# 50%    2.169960e+05
# 75%    7.334630e+05
# max    1.170022e+07
